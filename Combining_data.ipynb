# %%
import os
import zipfile
import pandas as pd

# %%
import os
import zipfile
import pandas as pd

# Paths
zip_files = [
    "/content/DL_SelectFields 1998 April.zip",
    "/content/DL_SelectFields 1999 April.zip",
    "/content/DL_SelectFields 2000 April.zip",
    "/content/DL_SelectFields 2001 April.zip",
    "/content/DL_SelectFields 2002 April.zip",
]
output_csv = "April_Combined_Dataset.csv"

# Creating a list to store dataframes
dataframes = []

# Extracting and reading the zip files
for zip_file in zip_files:
    if zip_file.endswith(".zip"):
        zip_dir = os.path.dirname(zip_file)

        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            extract_path = os.path.join(zip_dir, "extracted")
            zip_ref.extractall(extract_path)

            for extracted_file in os.listdir(extract_path):
                if extracted_file.endswith(".csv"):
                    csv_path = os.path.join(extract_path, extracted_file)
                    df = pd.read_csv(csv_path)
                    dataframes.append(df)

# Combine all dataframes
if dataframes:
    combined_df = pd.concat(dataframes, ignore_index=True)
    combined_df.to_csv(output_csv, index=False)
    print(f"Combined dataset saved as {output_csv}")
# Out:
# Combined dataset saved as April_Combined_Dataset.csv

# %%
april_combined = pd.read_csv("/content/april_combined_dataset.csv")
april_combined.describe()
# Out:
#                YEAR    QUARTER      MONTH  DAY_OF_MONTH   DAY_OF_WEEK  \
# count  2.308855e+06  2308855.0  2308855.0  2.308855e+06  2.308855e+06
# mean   2.000024e+03        2.0        4.0  1.550948e+01  3.940797e+00
# std    1.394001e+00        0.0        0.0  8.655023e+00  2.001780e+00
# min    1.998000e+03        2.0        4.0  1.000000e+00  1.000000e+00
# 25%    1.999000e+03        2.0        4.0  8.000000e+00  2.000000e+00
# 50%    2.000000e+03        2.0        4.0  1.600000e+01  4.000000e+00
# 75%    2.001000e+03        2.0        4.0  2.300000e+01  6.000000e+00
# max    2.002000e+03        2.0        4.0  3.000000e+01  7.000000e+00
#
#            DEP_TIME     DEP_DEL15  DEP_DELAY_GROUP      TAXI_OUT  \
# count  2.265411e+06  2.265411e+06     2.265411e+06  2.265411e+06
# mean   1.350217e+03  1.594629e-01     4.676458e-02  1.524942e+01
# std    4.840688e+02  3.661073e-01     1.707352e+00  1.009182e+01
# min    1.000000e+00  0.000000e+00    -2.000000e+00  1.000000e+00
# 25%    9.290000e+02  0.000000e+00    -1.000000e+00  1.000000e+01
# 50%    1.335000e+03  0.000000e+00     0.000000e+00  1.300000e+01
# 75%    1.742000e+03  0.000000e+00     0.000000e+00  1.800000e+01
# max    2.400000e+03  1.000000e+00     1.200000e+01  1.439000e+03
#
#          WHEELS_OFF     ARR_DEL15     CANCELLED  CANCELLATION_CODE  \
# count  2.265252e+06  2.260670e+06  2.308855e+06                0.0
# mean   1.371126e+03  1.992980e-01  1.881625e-02                NaN
# std    4.867113e+02  3.994726e-01  1.358757e-01                NaN
# min    1.000000e+00  0.000000e+00  0.000000e+00                NaN
# 25%    9.430000e+02  0.000000e+00  0.000000e+00                NaN
# 50%    1.348000e+03  0.000000e+00  0.000000e+00                NaN
# 75%    1.757000e+03  0.000000e+00  0.000000e+00                NaN
# max    2.400000e+03  1.000000e+00  1.000000e+00                NaN
#
#            DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME      DISTANCE  \
# count  2.308855e+06      2.308842e+06         2.260670e+06  2.308855e+06
# mean   2.053399e-03      1.271402e+02         1.258482e+02  7.439306e+02
# std    4.526790e-02      6.962120e+01         7.019888e+01  5.629357e+02
# min    0.000000e+00     -3.600000e+01        -3.900000e+01  2.100000e+01
# 25%    0.000000e+00      7.500000e+01         7.300000e+01  3.280000e+02
# 50%    0.000000e+00      1.090000e+02         1.070000e+02  5.900000e+02
# 75%    0.000000e+00      1.600000e+02         1.590000e+02  9.870000e+02
# max    1.000000e+00      6.700000e+02         8.500000e+02  4.962000e+03
#
#        DISTANCE_GROUP
# count    2.308855e+06
# mean     3.447796e+00
# std      2.225243e+00
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      3.000000e+00
# 75%      4.000000e+00
# max      1.100000e+01

# %%
april_combined.shape
# Out:
# (2308855, 23)

# %%
april_combined.YEAR.value_counts()
# Out:
# YEAR
# 2001    514187
# 2000    463263
# 1999    450620
# 1998    442644
# 2002    438141
# Name: count, dtype: int64

# %%
april_combined.sample(10)
# Out:
#          YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 1796581  2001        2      4            26            4                UA
# 689650   1999        2      4            17            6                NW
# 957203   2000        2      4             5            3                CO
# 171743   1998        2      4            12            7                UA
# 575897   1999        2      4             9            5                WN
# 834880   1999        2      4            27            2                CO
# 1526566  2001        2      4            10            2                WN
# 1974118  2002        2      4             8            1                AA
# 132823   1998        2      4             9            4                WN
# 586259   1999        2      4            10            6                UA
#
#         ORIGIN ORIGIN_STATE_ABR DEST DEST_STATE_ABR  ...  TAXI_OUT  \
# 1796581    DCA               VA  ORD             IL  ...      14.0
# 689650     HOU               TX  MSP             MN  ...      13.0
# 957203     IAH               TX  ORF             VA  ...      18.0
# 171743     SFO               CA  SNA             CA  ...      20.0
# 575897     CLE               OH  BNA             TN  ...      13.0
# 834880     SEA               WA  EWR             NJ  ...      14.0
# 1526566    HOU               TX  DAL             TX  ...       4.0
# 1974118    SJC               CA  DEN             CO  ...      23.0
# 132823     ONT               CA  OAK             CA  ...      11.0
# 586259     DEN               CO  LAX             CA  ...       8.0
#
#          WHEELS_OFF  ARR_DEL15  CANCELLED  CANCELLATION_CODE  DIVERTED  \
# 1796581      1212.0        0.0        0.0                NaN       0.0
# 689650       1109.0        0.0        0.0                NaN       0.0
# 957203       1917.0        0.0        0.0                NaN       0.0
# 171743       1144.0        0.0        0.0                NaN       0.0
# 575897        738.0        0.0        0.0                NaN       0.0
# 834880        742.0        0.0        0.0                NaN       0.0
# 1526566      1934.0        0.0        0.0                NaN       0.0
# 1974118      1309.0        0.0        0.0                NaN       0.0
# 132823       1812.0        1.0        0.0                NaN       0.0
# 586259        934.0        0.0        0.0                NaN       0.0
#
#          CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  DISTANCE  DISTANCE_GROUP
# 1796581             120.0                117.0     612.0               3
# 689650              166.0                158.0    1057.0               5
# 957203              174.0                170.0    1201.0               5
# 171743               90.0                 85.0     372.0               2
# 575897               90.0                 91.0     448.0               2
# 834880              308.0                313.0    2401.0              10
# 1526566              55.0                 47.0     239.0               1
# 1974118             164.0                151.0     949.0               4
# 132823               70.0                 70.0     362.0               2
# 586259              149.0                141.0     862.0               4
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Percentage of missing data points for each column

# %%
100*april_combined.isnull().sum()/april_combined.shape[0]
# Out:
# YEAR                     0.000000
# QUARTER                  0.000000
# MONTH                    0.000000
# DAY_OF_MONTH             0.000000
# DAY_OF_WEEK              0.000000
# OP_UNIQUE_CARRIER        0.000000
# ORIGIN                   0.000000
# ORIGIN_STATE_ABR         0.000000
# DEST                     0.000000
# DEST_STATE_ABR           0.000000
# DEP_TIME                 1.881625
# DEP_DEL15                1.881625
# DEP_DELAY_GROUP          1.881625
# TAXI_OUT                 1.881625
# WHEELS_OFF               1.888512
# ARR_DEL15                2.086965
# CANCELLED                0.000000
# CANCELLATION_CODE      100.000000
# DIVERTED                 0.000000
# CRS_ELAPSED_TIME         0.000563
# ACTUAL_ELAPSED_TIME      2.086965
# DISTANCE                 0.000000
# DISTANCE_GROUP           0.000000
# dtype: float64

# %%
april_combined.drop(columns = ['CANCELLATION_CODE'], inplace = True)

# %%
april_combined.dropna(inplace = True)

# %%
april_combined.shape
# Out:
# (2260511, 22)

# %%
2260511 - 2308855
# Out:
# -48344
